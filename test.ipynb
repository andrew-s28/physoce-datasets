# %%
import matplotlib.pyplot as plt
import xarray as xr

# %%
ds = xr.open_dataset("data/era5_reanalysis_2023-12-01_2023-12-03.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:     (valid_time: 12, latitude: 121, longitude: 121)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 96B 2023-12-01 ... 2023-12-03T18:...
#     expver      (valid_time) <U4 192B ...
#   * latitude    (latitude) float64 968B 60.0 59.75 59.5 ... 30.5 30.25 30.0
#   * longitude   (longitude) float64 968B 210.0 210.2 210.5 ... 239.5 239.8 240.0
#     number      int64 8B ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 703kB ...
#     v10         (valid_time, latitude, longitude) float32 703kB ...
#     d2m         (valid_time, latitude, longitude) float32 703kB ...
#     t2m         (valid_time, latitude, longitude) float32 703kB ...
#     sst         (valid_time, latitude, longitude) float32 703kB ...
#     sp          (valid_time, latitude, longitude) float32 703kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
# ...

# %%
(ds.strd.mean(dim=["latitude", "longitude"]) / 3600).plot()

# %%
ds = xr.open_dataset("data/copernicus_marine_eke_2023-12-30_2023-12-31.nc")

# %%
ds_mean = ds.mean(dim="time")

# %%
ds
# Out:
# dtype('float32')

# %%
plt.pcolormesh(
    ds_mean["longitude"],
    ds_mean["latitude"],
    ds_mean["eke"],
)
plt.colorbar()
